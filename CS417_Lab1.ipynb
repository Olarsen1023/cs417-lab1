# %% [markdown]
# <a href="https://colab.research.google.com/github/Olarsen1023/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date:** [Today's Date]
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
favorite_food = "steak"
favorite_number = 28
favorite_color = "Lavander"

print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: steak
# My favorite number is: 28
# My favorite color is: Lavander

# %%
month = "July"
day = "18"

print("I am getting married in " + month + " on the " + day + "th")
# Out:
# I am getting married in July on the 18th
